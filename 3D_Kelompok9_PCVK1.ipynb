# %% [markdown]
# <a href="https://colab.research.google.com/github/HanifRafandi014/3D_Jobsheet_PCVK_Sem5/blob/master/3D_Kelompok9_PCVK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Kelompok 9 PCVK Pertemuan 1
#
# Nama Anggota :
#
# *   Alfi Surya Pratama/ 2141720075 / 03
# *   Hanif Naufal Rafandi / 2141720127 / 14
# *   Mukhammad Nuril Haidar / 2141720208 /
#
# Kelas : 3D

# %% [markdown]
# # **Import Library Python**

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# #Menyimpan URL dari beberapa image
# Membuat List untuk menyimpan url

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://images.unsplash.com/photo-1617491725459-6d720083ee43?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8Mnx8Y2xvdWQlMjBhZXN0aGV0aWN8ZW58MHx8MHx8fDA%3D&w=1000&q=30.jpg",
       "https://wallpapers.com/images/hd/beach-aesthetic-pictures-ix0zyyi934p6rzuu.jpg",
      "https://images.unsplash.com/photo-1623860434284-7ea639cea5c2?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8Mnx8YWVzdGhldGljJTIwY2F0fGVufDB8fDB8fHww&w=1000&q=80.jpg"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=1000x666>
# <PIL.Image.Image image mode=RGB size=1000x332>
# <PIL.Image.Image image mode=RGB size=1000x331>

# %% [markdown]
# #Melihat ukuran resolusi File image

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  331  x  500
# <PIL.Image.Image image mode=RGB size=500x331>

# %% [markdown]
# Mengakses pixel dengan memberi garis diagonal menyilang

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)


#garis horizontal tanpa loop
image_3[int(tinggi/2),:]=[255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x331>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
'''
#membuat garis horizontal ditengah image
for y in range (lebar): 0,1,2,....399
  image_3[int((tinggi)/2),y] = [255,255,255]
'''
'''
#membuat garis vertikal ditengah image
for x in range (tinggi):
  image_3[x,int((lebar)/2)] = [255,255,255]
'''
'''
#membuat garis diagonal
for y in range (tinggi):
  image_3[y,int(y*(lebar/tinggi))] = [255,0,0]
  image_3[y,lebar-1-int(y*(lebar/tinggi))] = [0,255,0]
'''
'''
#membuat garis horisontal ditengah dengan panjang tertentu
for y in range (100,200):
  image_3[int((tinggi)/2),y] = [255,255,255]
'''

#membuat kotak dari kumpulan pixel warna putih
for y in range (250,320):
  for x in range (150,230):
    image_3[x,y] = [255,255,255]


final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x331>

# %% [markdown]
# # Akses file KTP dan tutup tiap bagian dari kartu identitas

# %% [markdown]
# 1.   Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib
# 2.   Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa konversi pada opencv
# 3.   Tutup tiap bagian tertentu dari kartu identitas tersebut. Kelompok 1 tutup bagian nomor NIK dan nama. Kelompok 2 tutup bagian TTL dan Jenis Kelamin. Kelompok 3 tutup bagian Gol. Darah dan TTD. Kelompok 4 tutup bagian Alamat dan Kecamatan. Kelompok 5 tutup bagian Agama dan Status Kawin. Kelompok 6 tutup Pekerjaan dan kewarganegaraan. Kelompok 7 tutup bagian berlaku hingga dan foto. Kelompok 8 tutup bagian kabupaten dan tanggal dikeluarkan KTP yang ada dibagian bawah foto. Kelompok 9 tutup bagian nama propinsi dan kabupaten di bagian paling atas KTP. Kelompok 10 tutup bagian RT/RW dan Kel/desa. Tutup menggunakan 2 kotak warna yang berbeda. Tidak boleh menggunakan fungsi rectangle openCV, fungsi ini akan dipelajari pada pertemuan 2

# %% [markdown]
# Step tugas untuk No 1

# %%
img_4 = cv.imread('KTP1.jpeg')
img_5 = cv.cvtColor(img_4, cv.COLOR_BGR2RGB)
cv2_imshow(img_4)
plt.imshow(img_5)
# Out:
# <PIL.Image.Image image mode=RGB size=600x373>

# %%
img_4s = np.copy(img_4)
#tutup bagian provinsi
for y in range (158,460):
  for x in range (5,22):
    img_4s[x,y] = [0,0,0]

#tutup bagian kabupaten
img_4ss = np.copy(img_4s)
for y in range (190,420):
  for x in range (25,45):
    img_4ss[x,y] = [0,255,255]
final_frame = cv.hconcat((img_4s, img_4ss))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=1200x373>
