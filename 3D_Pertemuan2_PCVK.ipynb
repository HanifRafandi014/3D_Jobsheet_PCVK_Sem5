# %% [markdown]
# <a href="https://colab.research.google.com/github/HanifRafandi014/3D_Jobsheet_PCVK_Sem5/blob/master/3D_Pertemuan2_PCVK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *    Nama Anggota :
# 1.   Alfi Surya / 2141720075
# 2.   Hanif Naufal Rafandi / 2141720127
# 3.   Mukhammad Nuril Haidar / 2141720208
#
# *   Kelas : 3D
# *   PCVK Pertemuan 2

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

img = cv.imread('/content/drive/MyDrive/Images/KTP.jpeg')
img_2 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
cv.rectangle(img_2, pt1=(650,30), pt2=(200,0), color=(224,233), thickness=cv.FILLED)
cv.rectangle(img_2, pt1=(550,37), pt2=(250,60), color=(123,123), thickness=cv.FILLED)

plt.imshow(img_2)
